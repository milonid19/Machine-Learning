# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import sklearn.datasets as ds
from sklearn.cluster import KMeans
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ## Create some data

# %%
plt.jet()
x, y = ds.make_blobs(centers=6, cluster_std=1)
# create 6 random clusters.  These may be overlapping
# x: nx2 matrix
# y: true cluster memeberhip
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=y, s=100)
plt.show()

# %% [markdown]
# ## Do k-means (and plot the result in a nice way)

# %%
km = KMeans(6)
# find 4 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3, s=100)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=200)

# %% [markdown]
# ## Demonstrate how k-means starts work with random state
#
# Note: you may want to play with the value for `random_state`

# %%
km1 = KMeans(5, max_iter=1, init="random", n_init=2, random_state=1)
hatY = km1.fit(x).labels_
mu = km1.cluster_centers_
plt.figure(figsize=(11,11))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %% [markdown]
# ## Demonstrate how k-means works with wrong scale.
#
# Let's make x1 10x smaller than x2

# %%
km1 = KMeans(5)
xx = x.copy()
xx[:,1] = xx[:,1]/10
hatY = km1.fit(xx).labels_
mu = km1.cluster_centers_
plt.figure(figsize=(11,11))
plt.scatter(xx[:,0], xx[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
